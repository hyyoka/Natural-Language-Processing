# %%
import pandas as pd

# %%
df = pd.read_csv("/content/generation-test.csv", error_bad_lines=False)
df
# Out:
#       IDX                      PROMPT
# 0       1   he aggravated her because
# 1       2  she aggravated him because
# 2       3       he amazed her because
# 3       4      she amazed him because
# 4       5       he amused her because
# ..    ...                         ...
# 487  1128               The meal that
# 488  1129              The woman that
# 489  1130            The jewelry that
# 490  1131             The dieter that
# 491  1132            The dessert that
#
# [492 rows x 2 columns]

# %%
new_lines = list(df["PROMPT"])
print(new_lines)
# Out:
# ['he aggravated her because', 'she aggravated him because', 'he amazed her because', 'she amazed him because', 'he amused her because', 'she amused him because', 'he annoyed her because', 'she annoyed him because', 'he apologized to her because', 'she apologized to him because', 'he bored her because', 'she bored him because', 'he charmed her because', 'she charmed him because', 'he confessed to her because', 'she confessed to him because', 'he deceived her because', 'she deceived him because', 'he disappointed her because', 'she disappointed him because', 'he exasperated her because', 'she exasperated him because', 'he fascinated her because', 'she fascinated him because', 'he frightened her because', 'she frightened him because', 'he humiliated her because', 'she humiliated him because', 'he infuriated her because', 'she infuriated him because', 'he inspires her because', 'she inspires him because', 'he intimidates her because', 'she intimidates him because', 'he offended her becau
# ...

# %%
# !git clone https://github.com/huggingface/transformers
# %cd transformers
# !pip install .
# !pip install -r ./examples/requirements.txt
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 66864 (delta 0), reused 9 (delta 0), pack-reused 66855
# Receiving objects: 100% (66864/66864), 49.77 MiB | 28.68 MiB/s, done.
# Resolving deltas: 100% (47496/47496), done.
# /content/transformers
# Processing /content/transformers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 3.2MB 7.9MB/s
# ...
#      |████████████████████████████████| 890kB 51.9MB/s
# ...
#   Created wheel for transformers: filename=transformers-4.4.0.dev0-cp37-none-any.whl size=1969146 sha256=4b79460d169fe05834ed9d15907dfd3c4311635aa284fe86f2a60ad3fc7acb73
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4f79tzhs/wheels/23/19/dd/2561a4e47240cf6b307729d58e56f8077dd0c698f5992216cf
# Successfully built transformers
# ...

# %% [markdown]
# # 모델을 사용하기 위해서는 pyarrow의 최신버전을 깔아야합니다. 구버전을 uninstall합니다.

# %%
# !pip uninstall pyarrow
# Out:
# Uninstalling pyarrow-3.0.0:
#   Would remove:
#     /usr/local/bin/plasma_store
#     /usr/local/lib/python3.7/dist-packages/pyarrow-3.0.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/pyarrow/*
# Proceed (y/n)? y
#   Successfully uninstalled pyarrow-3.0.0

# %%
# !pip install pyarrow
# Out:
# ...
#      |████████████████████████████████| 20.7MB 42.6MB/s
# ...

# %% [markdown]
# # Generate the sentence
#
# - 고정 seed 없애기

# %%
temperature = [0.9]

# %%
# !python /content/transformers/examples/text-generation/run_generation.py \
                --model_type=gpt2 \
                --num_return_sequences=1\
                --model_name_or_path=gpt2\
                --temperature=0.9
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# === GENERATED SEQUENCE 6 ===
# a man waited for a woman because he was afraid of her being abused and had to listen to him for a while.
#
# 3
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# === GENERATED SEQUENCE 7 ===
# a man waited for a woman because he saw an invisible, blue beam in the sky. She was bleeding profusely. He wasn
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# === GENERATED SEQUENCE 8 ===
# a man waited for a woman because he thought it would be too much work for him to run for president. It was also the last
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# === GENERATED SEQUENCE 9 ===
# a man waited for a woman because she was too slow and for at least a few minutes they approached.
#
#
# "Wait, that
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# === GENERATED SEQUENCE 0 ===
# ...
